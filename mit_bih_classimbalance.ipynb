# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("denoised_ecg_segments.csv")

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.112834 -0.121476 -0.126965 -0.123497 -0.111493 -0.096003 -0.081663
# 1 -0.120074 -0.109806 -0.095035 -0.084257 -0.081060 -0.081954 -0.080350
# 2 -0.072732 -0.052075 -0.033152 -0.014940  0.002883  0.016991  0.023469
# 3 -0.034096 -0.029002 -0.017737 -0.008208 -0.009743 -0.024991 -0.046136
# 4 -0.007874 -0.000619  0.008726  0.015783  0.015664  0.008647  0.001691
#
#           7         8         9  ...       171       172       173       174  \
# 0 -0.069751 -0.059851 -0.053301  ... -0.351163 -0.366652 -0.382175 -0.397097
# 1 -0.072425 -0.059298 -0.043935  ... -0.174571 -0.187954 -0.197343 -0.197514
# 2  0.023783  0.026904  0.044241  ... -0.415153 -0.447288 -0.474184 -0.496211
# 3 -0.059235 -0.053112 -0.025296  ... -0.386841 -0.400270 -0.424229 -0.450600
# 4  0.003593  0.017827  0.039802  ... -0.219527 -0.234686 -0.263699 -0.294935
#
#         175       176       177       178       179  target
# ...

# %%
# df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#                0         1         2         3         4         5         6  \
# 0      -0.112834 -0.121476 -0.126965 -0.123497 -0.111493 -0.096003 -0.081663
# 1      -0.120074 -0.109806 -0.095035 -0.084257 -0.081060 -0.081954 -0.080350
# 2      -0.072732 -0.052075 -0.033152 -0.014940  0.002883  0.016991  0.023469
# 3      -0.034096 -0.029002 -0.017737 -0.008208 -0.009743 -0.024991 -0.046136
# 4      -0.007874 -0.000619  0.008726  0.015783  0.015664  0.008647  0.001691
# ...          ...       ...       ...       ...       ...       ...       ...
# 109180 -0.177956 -0.198003 -0.216868 -0.230646 -0.236108 -0.230634 -0.214025
# 109181 -0.087719 -0.095463 -0.112920 -0.133313 -0.147428 -0.148270 -0.134837
# 109182 -0.255230 -0.269239 -0.270953 -0.260495 -0.239668 -0.212537 -0.185987
# 109183 -0.259833 -0.269297 -0.269056 -0.260234 -0.244891 -0.225653 -0.206505
# 109184  0.129238  0.142030  0.144123  0.135473  0.120872  0.106825  0.097362
#
# ...

# %%
df['target'].value_counts()
# Out:
# 1    90514
# 2     8007
# 4     6956
# 3     2923
# 0      785
# Name: target, dtype: int64

# %%
# !pip install imblearn
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

# %%
X = df.drop('target', axis=1)

# %%
y = df['target']

# %%
print("Original class distribution:")
print(y.value_counts())
# Out:
# Original class distribution:
# 1    90514
# 2     8007
# 4     6956
# 3     2923
# 0      785
# Name: target, dtype: int64

# %%
undersample_strategy = {1: 2000, 2: 2000, 4: 2000, 3: 2000}
undersample = RandomUnderSampler(sampling_strategy=undersample_strategy, random_state=42)

# %%
X_under, y_under = undersample.fit_resample(X, y)

# %%
minority_class_0 = df[df['target'] == 0]

# %%
df_combined = pd.concat([pd.DataFrame(X_under), pd.DataFrame(y_under)], axis=1)
df_combined = pd.concat([df_combined, minority_class_0], axis=0)

# %%
X_combined = df_combined.drop('target', axis=1)
y_combined = df_combined['target']

# %%
oversample_strategy = {0: 2000}
oversample = RandomOverSampler(sampling_strategy=oversample_strategy, random_state=42)

# %%
X_resampled, y_resampled = oversample.fit_resample(X_combined, y_combined)

# %%
print("Resampled class distribution:")
print(y_resampled.value_counts())
# Out:
# Resampled class distribution:
# 0    2000
# 1    2000
# 2    2000
# 3    2000
# 4    2000
# Name: target, dtype: int64

# %%
df_resampled = pd.concat([pd.DataFrame(X_resampled), pd.DataFrame(y_resampled, columns=['target'])], axis=1)

# %%
df_resampled.to_csv('resampled_dataset.csv', index=False)

# %%
df_resampled.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.021396 -0.024454 -0.025602 -0.033167 -0.046346 -0.053598 -0.041849
# 1 -0.065446 -0.113605 -0.132356 -0.123176 -0.099631 -0.076035 -0.058774
# 2  0.597245  0.609343  0.616054  0.615580  0.608934  0.599329  0.589872
# 3  0.415356  0.406773  0.396699  0.385015  0.369871  0.351091  0.332162
# 4 -0.077010 -0.054180 -0.015751  0.032942  0.078915  0.109189  0.121749
#
#           7         8         9  ...       171       172       173       174  \
# 0 -0.008744  0.033132  0.064087  ... -0.203703 -0.216824 -0.231263 -0.232960
# 1 -0.046599 -0.037302 -0.032211  ...  0.706370  0.737433  0.751696  0.740411
# 2  0.581167  0.570926  0.556225  ... -0.466576 -0.448324 -0.431047 -0.414286
# 3  0.318586  0.313899  0.316959  ... -0.344787 -0.327214 -0.311647 -0.297288
# 4  0.128960  0.148012  0.185541  ...  0.599737  0.647817  0.692601  0.719140
#
#         175       176       177       178       179  target
# ...

# %%
df_resampled.shape
# Out:
# (10000, 181)

# %%
df_resampled['target'].value_counts()
# Out:
# 0    2000
# 1    2000
# 2    2000
# 3    2000
# 4    2000
# Name: target, dtype: int64

# %%
df=pd.read_csv('mit_bih_resampled.csv')

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.021396 -0.024454 -0.025602 -0.033167 -0.046346 -0.053598 -0.041849
# 1 -0.065446 -0.113605 -0.132356 -0.123176 -0.099631 -0.076035 -0.058774
# 2  0.597245  0.609343  0.616054  0.615580  0.608934  0.599329  0.589872
# 3  0.415356  0.406773  0.396699  0.385015  0.369871  0.351091  0.332162
# 4 -0.077010 -0.054180 -0.015751  0.032942  0.078915  0.109189  0.121749
#
#           7         8         9  ...       171       172       173       174  \
# 0 -0.008744  0.033132  0.064087  ... -0.203703 -0.216824 -0.231263 -0.232960
# 1 -0.046599 -0.037302 -0.032211  ...  0.706370  0.737433  0.751696  0.740411
# 2  0.581167  0.570926  0.556225  ... -0.466576 -0.448324 -0.431047 -0.414286
# 3  0.318586  0.313899  0.316959  ... -0.344787 -0.327214 -0.311647 -0.297288
# 4  0.128960  0.148012  0.185541  ...  0.599737  0.647817  0.692601  0.719140
#
#         175       176       177       178       179  target
# ...

# %%
df.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 176       0
# 177       0
# 178       0
# 179       0
# target    0
# Length: 181, dtype: int64

# %%
df.describe()
# Out:
#                   0             1             2             3             4  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -0.076075     -0.078194     -0.080045     -0.081679     -0.083185
# std        0.538821      0.538789      0.538746      0.538581      0.538610
# min       -6.622196     -6.832047     -6.979191     -7.082238     -7.156667
# 25%       -0.348178     -0.347643     -0.344291     -0.343395     -0.339179
# 50%       -0.157934     -0.157357     -0.159194     -0.157826     -0.158958
# 75%        0.145584      0.134262      0.129478      0.125518      0.122522
# max        5.823471      5.741622      5.621164      5.450747      5.207922
#
#                   5             6             7             8             9  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -0.084730     -0.086508     -0.088626     -0.091006     -0.093395
# ...

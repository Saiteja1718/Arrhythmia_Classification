# 2      -0.012856 -0.009099  0.002670  0.014798  0.019607  0.015061       1
# 3      -0.000504  0.006521  0.005012 -0.005154 -0.017405 -0.024057       1
# 4       0.001399  0.000910 -0.001072 -0.000728  0.001449  0.000692       1
# ...          ...       ...       ...       ...       ...       ...     ...
# 169635  0.200494  0.206596  0.212933  0.218307  0.222271  0.225584       4
# 169636 -0.059546 -0.056219 -0.051647 -0.045585 -0.038886 -0.032853       1
# 169637 -0.037463 -0.032311 -0.027128 -0.021578 -0.016022 -0.011204       1
# 169638 -0.031812 -0.026737 -0.021678 -0.016671 -0.011196 -0.005316       1
# 169639 -0.048983 -0.044688 -0.040344 -0.036172 -0.031711 -0.026760       1
#
# [169640 rows x 181 columns]

# %%
df['target'].value_counts()
# Out:
# 1    152340
# 4     14994
# 3      2099
# 0       201
# 2         6
# Name: target, dtype: int64

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\sai teja\appdata\local\programs\python\python310\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\sai teja\appdata\local\programs\python\python310\lib\site-packages (from imblearn) (0.12.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\sai teja\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn->imblearn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\sai teja\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn->imblearn) (1.10.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\sai teja\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn->imblearn) (1.2.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\sai teja\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sai teja\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn->imblearn) (3.1.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

# %%
X = df.drop('target', axis=1)

# %%
y = df['target']

# %%
print("Original class distribution:")
print(y.value_counts())
# Out:
# Original class distribution:
# 1    152340
# 4     14994
# 3      2099
# 0       201
# 2         6
# Name: target, dtype: int64

# %%
undersample_strategy = {1: 2000,4: 2000, 3: 2000}
undersample = RandomUnderSampler(sampling_strategy=undersample_strategy, random_state=42)

# %%
X_under, y_under = undersample.fit_resample(X, y)

# %%
minority_class_0 = df[df['target'] == 0]

# %%
df_combined = pd.concat([pd.DataFrame(X_under), pd.DataFrame(y_under)], axis=1)
df_combined = pd.concat([df_combined, minority_class_0], axis=0)

# %%
X_combined = df_combined.drop('target', axis=1)
y_combined = df_combined['target']

# %%
oversample_strategy = {0: 2000,2:2000}
oversample = RandomOverSampler(sampling_strategy=oversample_strategy, random_state=42)

# %%
X_resampled, y_resampled = oversample.fit_resample(X_combined, y_combined)

# %%
print("Resampled class distribution:")
print(y_resampled.value_counts())
# Out:
# Resampled class distribution:
# 0    2000
# 1    2000
# 2    2000
# 3    2000
# 4    2000
# Name: target, dtype: int64

# %%
df_resampled = pd.concat([pd.DataFrame(X_resampled), pd.DataFrame(y_resampled, columns=['target'])], axis=1)

# %%
df_resampled.to_csv('resampled_dataset.csv', index=False)

# %%
df_resampled.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.001399 -0.009637 -0.014483 -0.008217  0.003079  0.009108  0.006485
# 1 -0.003450 -0.000507  0.007082  0.008675  0.000749 -0.007706 -0.006197
# 2 -0.009487 -0.009848 -0.003642 -0.001382 -0.004602 -0.003511  0.009169
# 3 -0.033187 -0.039688 -0.035787 -0.023284 -0.017343 -0.025122 -0.036150
# 4 -0.042631 -0.055215 -0.044489 -0.011118  0.020328  0.021075 -0.011683
#
#           7         8         9  ...       171       172       173       174  \
# 0  0.001058 -0.000345  0.002199  ...  0.016842  0.020552  0.027698  0.034403
# 1  0.004054  0.011627  0.008940  ... -0.015202  0.000804  0.012121  0.011672
# 2  0.027220  0.037831  0.036531  ...  0.121585  0.132136  0.149422  0.175916
# 3 -0.034832 -0.019275 -0.004171  ...  0.033417  0.026292  0.019084  0.007791
# 4 -0.049862 -0.063069 -0.046808  ...  0.033473  0.053263  0.071243  0.069895
#
#         175       176       177       178       179  target
# 0  0.034483  0.027981  0.021803  0.021277  0.023957       0
# 1  0.005584  0.004995  0.012480  0.020793  0.023928       0
# 2  0.206855  0.226794  0.221882  0.198265  0.181316       0
# 3 -0.003452 -0.006242  0.001555  0.012435  0.017095       0
# 4  0.047216  0.019986  0.007720  0.013408  0.024234       0
#
# [5 rows x 181 columns]

# %%
df_resampled.shape
# Out:
# (10000, 181)

# %%
df_resampled['target'].value_counts()
# Out:
# 0    2000
# 1    2000
# 2    2000
# 3    2000
# 4    2000
# Name: target, dtype: int64

# %%
df=pd.read_csv('incart_resampled.csv')

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.